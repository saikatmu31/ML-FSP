# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
height = [3,12,5,18,45]
bars = ('A','B','C','D','E')
y_pos = np.arange(len(bars))
plt.bar(y_pos,height)
plt.xticks(y_pos,bars)
plt.show()

# %%
cd Downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads'
# C:\Users\Saikat\Downloads\ML Data Files\data

# %%
cd "ML Data Files"
# Out:
# [WinError 2] The system cannot find the file specified: 'ML Data Files'
# C:\Users\Saikat\Downloads\ML Data Files\data

# %%
cd data/
# Out:
# [WinError 2] The system cannot find the file specified: 'data/'
# C:\Users\Saikat\Downloads\ML Data Files\data

# %%
mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
mtcars.shape
# Out:
# (32, 12)

# %%
import seaborn as sns

# %%
res = sns.barplot(x=mtcars['cyl'],y=mtcars['carb'])

# %%
res = sns.barplot(x='cyl',y='carb',data=mtcars)

# %%
res = sns.barplot(x='cyl',y='carb',data=mtcars,color='red')

# %%
res = sns.barplot(x='cyl',y='carb',data=mtcars,palette='rocket')

# %%
height = [3,12,5,18,45]
bars = ('A','B','C','D','E')
y_pos = np.arange(len(bars))
plt.barh(y_pos,height,color = ["red","blue",'green','gray','purple'])
plt.yticks(y_pos,bars)
plt.show()

# %%
height = [3,12,5,18,45]
bars = ('A','B','C','D','E')
y_pos = np.arange(len(bars))
plt.barh(y_pos,height,color=[0.2,0.2,0.2,0.2],edgecolor="blue")
plt.yticks(y_pos,bars)
plt.show()

# %%
height = [3,12,5,18,45]
bars = ('A','B','C','D','E')
y_pos = np.arange(len(bars))
plt.barh(y_pos,height,color=[0.2,0.2,0.2,0.2],edgecolor="blue")
plt.yticks(y_pos,bars)
plt.title("My Sample Title")
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
#Scatter Plot
df = pd.DataFrame({'x_values':range(1,101),'y_values':np.random.randn(100)*15+range(1,101)})
plt.plot('x_values','y_values',data=df,linestyle='none',marker='1')
plt.show()

# %%
x = np.random.randint(10,60,(50))

# %%
x
# Out:
# array([28, 32, 44, 30, 39, 16, 57, 58, 29, 54, 22, 49, 14, 15, 36, 27, 42,
#        15, 59, 20, 32, 17, 23, 37, 53, 57, 20, 57, 27, 54, 11, 32, 12, 38,
#        27, 47, 21, 50, 17, 36, 52, 39, 12, 58, 44, 32, 59, 39, 39, 24])

# %%
no = list(x)

# %%
no
# Out:
# [28,
#  32,
#  44,
#  30,
#  39,
#  16,
#  57,
#  58,
#  29,
#  54,
#  22,
#  49,
#  14,
#  15,
#  36,
#  27,
#  42,
#  15,
#  59,
#  20,
#  32,
#  17,
#  23,
#  37,
#  53,
#  57,
#  20,
#  57,
#  27,
#  54,
#  11,
#  32,
#  12,
#  38,
#  27,
#  47,
#  21,
#  50,
#  17,
#  36,
#  52,
#  39,
#  12,
#  58,
#  44,
#  32,
#  59,
#  39,
#  39,
#  24]

# %%
l = [10,20,30,40,50,60]
plt.hist(x=no,color="b",bins=l,edgecolor="r")
plt.title("wscube")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show(no)

# %%
l = [10,20,30,40,50,60]
plt.hist(x=no,color="b",bins="auto",range=(0,200),edgecolor="r")
plt.title("wscube")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show(no)

# %%
plt.rcParams["figure.figsize"]=(20,5)
size_of_groups = [12,11,3,30]
plt.pie(size_of_groups,explode=(0,0.2,0,0.1))
plt.show()

# %%
plt.rcParams["figure.figsize"]=(20,5)
size_of_groups = [12,11,3,30]
#lables = ["Gr-A","Gr-B","Gr-C","Gr-D"]
lables = "Gr-A","Gr-B","Gr-C","Gr-D"
plt.pie(size_of_groups,explode=(0.2,0,0,0),labels=lables,labeldistance=1.2)
plt.show()

# %%
plt.rcParams["figure.figsize"]=(20,5)
size_of_groups = [12,11,3,30]
#lables = ["Gr-A","Gr-B","Gr-C","Gr-D"]
lables = "Gr-A","Gr-B","Gr-C","Gr-D"
plt.pie(size_of_groups,explode=(0.2,0,0,0),wedgeprops={'linewidth':1,'edgecolor':"white"},labels=lables,labeldistance=1.2)
plt.show()

# %%
plt.rcParams["figure.figsize"]=(20,5)
size_of_groups = [12,11,3,30]
#lables = ["Gr-A","Gr-B","Gr-C","Gr-D"]
lables = "Gr-A","Gr-B","Gr-C","Gr-D"
colors = ('#F4BE2C','#E03B8B','#5A20CB','#51E1ED')
plt.pie(size_of_groups,explode=(0.2,0,0,0),wedgeprops={'linewidth':5,'edgecolor':"white"},labels=lables,labeldistance=1.2,colors=colors)
plt.show()

# %%
tempData = pd.read_csv('2009-temp-monthly.csv',names=["temp"])

# %%
temperature_data=list(tempData["temp"])
len(temperature_data)
# Out:
# 12

# %%
temperature_data = list(tempData["temp"])
temperature_data
# Out:
# [5.980645161290322,
#  6.732142857142856,
#  11.022580645161293,
#  14.626666666666669,
#  16.561290322580643,
#  19.683333333333334,
#  20.203225806451616,
#  20.77096774193549,
#  18.17,
#  14.916129032258068,
#  11.283333333333331,
#  5.82258064516129]

# %%
import csv
with open("2009-temp-monthly.csv")as csv_file:
    csv_reader = csv.reader(csv_file,quoting=csv.QUOTE_NONNUMERIC)
    temperature=[x[0] for x in csv_reader]
    
month_names = ["J","F","M","A","M","J","J","A","S","O","N","D"]
months = range(12)
plt.title("Monthly Temperature 2009")
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.xticks(months,month_names)
plt.stem(months,temperature_data,use_line_collection =  True)
plt.show()

# %%
len(temperature)
# Out:
# 12

# %%
sns.countplot(x='cyl',data=mtcars,palette='Set1')
# Out:
# <AxesSubplot:xlabel='cyl', ylabel='count'>

# %%
sns.countplot(x='carb',data=mtcars,palette='Set1')
# Out:
# <AxesSubplot:xlabel='carb', ylabel='count'>

# %%
sns.countplot(y='gear',data=mtcars,palette='rocket')
# Out:
# <AxesSubplot:xlabel='count', ylabel='gear'>

# %%
sns.countplot(x='gear',hue='cyl',data=mtcars,palette='Set1')
# Out:
# <AxesSubplot:xlabel='gear', ylabel='count'>

# %%
x=np.linspace(0,10,1000)
plt.plot(x,np.sin(x),x,np.cos(x),x,np.sin(x))

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')

# %%
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))
x=np.linspace(-6,6,30)
y=np.linspace(-6,6,30)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
fig=plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X,Y,Z,50,cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
url5 = 'http://bit.ly/drinksbycountry'
drinks  = pd.read_csv(url5)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
mean_data = drinks.groupby("country").mean()

# %%
mean_data
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0              0.0            0.0
# Albania               89.0            132.0           54.0
# Algeria               25.0              0.0           14.0
# Andorra              245.0            138.0          312.0
# Angola               217.0             57.0           45.0
# ...                    ...              ...            ...
# Venezuela            333.0            100.0            3.0
# Vietnam              111.0              2.0            1.0
# Yemen                  6.0              0.0            0.0
# Zambia                32.0             19.0            4.0
# Zimbabwe              64.0             18.0            4.0
#
#              total_litres_of_pure_alcohol
# country
# Afghanistan                           0.0
# Albania                               4.9
# Algeria                               0.7
# Andorra                              12.4
# ...

# %%
height = list(mean_data["country"])
bars = list(mean_data["total_litres_of_pure_alcohol"])
y_pos = np.arange(len(bars))
plt.bar(y_pos,height)
plt.xticks(y_pos,bars)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
height = mean_data['country']
bars = mean_data['total_litres_of_pure_alcohol']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
